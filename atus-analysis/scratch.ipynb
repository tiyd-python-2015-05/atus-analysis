# %%
import pandas as pd
import matplotlib.pyplot as plt
from atus_analysis import *

# %%
# %matplotlib inline

# %%
res_data = pd.read_csv("../atusdata/atusresp_2013.dat")
res_sub_data = res_data.loc[:, ['TUCASEID', 'TEIO1COW']]

# %%
indexed_res_sub_data = res_sub_data.set_index(['TUCASEID'])

# %%
indexed_res_sub_data.head(10)
# Out:
#                 TEIO1COW
# TUCASEID
# 20130101130004        -1
# 20130101130112         2
# 20130101130123        -1
# 20130101130611         4
# 20130101130616         5
# 20130101130619        -1
# 20130101130658        -1
# 20130101130670         6
# 20130101130734         4
# 20130101130735         6

# %%
all_data = multi_merged_df()

# %%
all_data.head()
# Out:
#          tucaseid        TUFINLWGT  TRYHHCHILD  TEAGE  TESEX  PEEDUCA  \
# 0  20130101130004  11899905.662034          12     22      2       40
# 1  20130101130112   4447638.009513           1     39      1       43
# 2  20130101130123  10377056.507734          -1     47      2       40
# 3  20130101130611   7731257.992805          -1     50      2       40
# 4  20130101130616   4725269.227067          -1     45      2       40
#
#    PTDTRACE  PEHSPNON  GTMETSTA  TELFS    ...     t500103  t500105  t500106  \
# 0         8         2         1      5    ...           0        0        0
# 1         1         2         1      1    ...           0        0        0
# 2         1         2         1      4    ...           0        0        0
# 3         1         1         1      1    ...           0        0        0
# 4         2         2         1      1    ...           0        0        0
#
#    t500107  GESTFIPS  HEFAMINC  HETENURE  PREMPHRS  PRMJIND1  TEIO1COW
# ...

# %%
cps_data = pd.read_csv("../atusdata/atuscps_2013.dat")
cps_sub_data = cps_data.loc[:, ['TUCASEID', 'TULINENO', 'GESTFIPS', 'HEFAMINC', 'HETENURE', 'PREMPHRS', 'PRMJIND1']]
cps = cps_sub_data[cps_sub_data['TULINENO'] == 1]
cps.pop('TULINENO')
# Out:
# 0        1
# 7        1
# 8        1
# 10       1
# 13       1
# 15       1
# 16       1
# 18       1
# 19       1
# 20       1
# 22       1
# 25       1
# 26       1
# 28       1
# 30       1
# 33       1
# 37       1
# 41       1
# 43       1
# 45       1
# 46       1
# 47       1
# 49       1
# 51       1
# 55       1
# 57       1
# 60       1
# 61       1
# 62       1
# 71       1
#         ..
# 67783    1
# 67787    1
# 67789    1
# 67791    1
# 67792    1
# 67794    1
# 67795    1
# 67797    1
# 67800    1
# 67804    1
# 67806    1
# 67807    1
# 67809    1
# 67810    1
# 67811    1
# 67812    1
# 67815    1
# 67817    1
# 67819    1
# 67822    1
# 67824    1
# 67828    1
# 67835    1
# 67837    1
# 67839    1
# 67843    1
# 67844    1
# 67846    1
# 67848    1
# 67851    1
# Name: TULINENO, dtype: int64

# %%
cps.head()
# Out:
#           TUCASEID  GESTFIPS  HEFAMINC  HETENURE  PREMPHRS  PRMJIND1
# 0   20130101130004        53        16         1         0        -1
# 7   20130101130046        26         6         2        18         4
# 8   20130101130086        12        16         1        22         8
# 10  20130101130112        48        15         1        18        13
# 13  20130101130123        36        15         1         0        -1

# %%
c = merge_w_cps()

# %%
c.head()
# Out:
#          tucaseid        TUFINLWGT  TRYHHCHILD  TEAGE  TESEX  PEEDUCA  \
# 0  20130101130004  11899905.662034          12     22      2       40
# 1  20130101130112   4447638.009513           1     39      1       43
# 2  20130101130123  10377056.507734          -1     47      2       40
# 3  20130101130611   7731257.992805          -1     50      2       40
# 4  20130101130616   4725269.227067          -1     45      2       40
#
#    PTDTRACE  PEHSPNON  GTMETSTA  TELFS    ...     t500101  t500103  t500105  \
# 0         8         2         1      5    ...           0        0        0
# 1         1         2         1      1    ...           0        0        0
# 2         1         2         1      4    ...           0        0        0
# 3         1         1         1      1    ...           0        0        0
# 4         2         2         1      1    ...           0        0        0
#
#    t500106  t500107  GESTFIPS  HEFAMINC  HETENURE  PREMPHRS  PRMJIND1
# ...

# %%
indexed_c = cps.set_index(['TUCASEID'])
# indexed_c = indexed_c.drop('tucaseid', 1)

# %%
indexed_c.head()
# Out:
#                 GESTFIPS  HEFAMINC  HETENURE  PREMPHRS  PRMJIND1
# TUCASEID
# 20130101130004        53        16         1         0        -1
# 20130101130046        26         6         2        18         4
# 20130101130086        12        16         1        22         8
# 20130101130112        48        15         1        18        13
# 20130101130123        36        15         1         0        -1

# %%
c['TUDIARYDAY']
# Out:
# 0        1
# 1        1
# 2        2
# 3        3
# 4        2
# 5        1
# 6        5
# 7        1
# 8        1
# 9        2
# 10       4
# 11       3
# 12       1
# 13       5
# 14       2
# 15       1
# 16       2
# 17       4
# 18       4
# 19       2
# 20       1
# 21       1
# 22       2
# 23       4
# 24       3
# 25       1
# 26       3
# 27       3
# 28       3
# 29       3
#         ..
# 11355    7
# 11356    1
# 11357    4
# 11358    5
# 11359    7
# 11360    4
# 11361    2
# 11362    7
# 11363    1
# 11364    1
# 11365    1
# 11366    7
# 11367    2
# 11368    2
# 11369    2
# 11370    6
# 11371    6
# 11372    1
# 11373    2
# 11374    7
# 11375    2
# 11376    1
# 11377    2
# 11378    4
# 11379    1
# 11380    2
# 11381    1
# 11382    5
# 11383    4
# 11384    1
# Name: TUDIARYDAY, dtype: int64

# %%
res_data = pd.read_csv("../atusdata/atusresp_2013.dat")

# %%
res_data.head()
# Out:
#          TUCASEID  TULINENO  TUYEAR  TUMONTH  TEABSRSN  TEERN  TEERNH1O  \
# 0  20130101130004         1    2013        1        -1     -1        -1
# 1  20130101130112         1    2013        1        -1     -1        -1
# 2  20130101130123         1    2013        1        -1     -1        -1
# 3  20130101130611         1    2013        1        -1     -1        -1
# 4  20130101130616         1    2013        1        -1     -1        -1
#
#    TEERNH2  TEERNHRO  TEERNHRY   ...     TXSPEMPNOT  TXSPUHRS  TXTCC  \
# 0       -1        -1        -1   ...             -1        -1      0
# 1       -1        -1         2   ...              0         0      0
# 2       -1        -1        -1   ...              0         0     -1
# 3       -1        -1         2   ...             -1        -1     -1
# 4       -1        -1         2   ...             -1        -1     -1
#
#    TXTCCTOT  TXTCOC  TXTHH  TXTNOHH  TXTO  TXTOHH  TXTONHH
# ...

# %%
data = make_multi_merged_df()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-371554d55bef> in <module>()
# ----> 1 data = make_multi_merged_df()
#
# NameError: name 'make_multi_merged_df' is not defined

# %%
data.head()

# %%
gov_vs_private = group_and_average(all_data, 'TEIO1COW', '1301', print_all=True)

# %%
gov_vs_private.plot(kind='bar')

# %%
state_rec = group_and_average(all_data, 'GESTFIPS', '1301', print_all=True)
# Out:
# 11385 people are included in this analysis.
# Count by group: GESTFIPS
# 1      193
# 2       24
# 4      186
# 5      138
# 6     1167
# 8      223
# 9      146
# 10      38
# 11      32
# 12     627
# 13     309
# 15      33
# 16      63
# 17     497
# 18     252
# 19     131
# 20     138
# 21     202
# 22     159
# 23      55
# 24     237
# 25     213
# 26     412
# 27     265
# 28     105
# 29     234
# 30      42
# 31      82
# 32     100
# 33      55
# 34     297
# 35      96
# 36     603
# 37     339
# 38      29
# 39     420
# 40     155
# 41     191
# 42     484
# 44      38
# 45     183
# 46      29
# 47     214
# 48     827
# 49     122
# 50      27
# 51     365
# 53     259
# 54      56
# 55     275
# 56      18
# Name: 1301, dtype: int64

# %%
state_rec.plot(kind='bar', figsize=(12,10))
